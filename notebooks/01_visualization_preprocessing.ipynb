# %% [markdown]
# ## Data Visualization and Preprocessing

# %% [markdown]
# ### Importing Data

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load sample datasets
fly = pd.read_csv('../data/samples/fly.csv')
back = pd.read_csv('../data/samples/back.csv')
breast = pd.read_csv('../data/samples/breast.csv')
free = pd.read_csv('../data/samples/free.csv')
free_quat = pd.read_csv('../data/samples/free_quat.csv')

# Set time_s as index for easier plotting
fly.set_index('time_s', inplace=True)
back.set_index('time_s', inplace=True)
breast.set_index('time_s', inplace=True)
free.set_index('time_s', inplace=True)
free_quat.set_index('time_s', inplace=True)

# %% [markdown]
# ### Data Visualization

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot acceleration data for Fly dataset
axs[0].plot(fly.index, fly['ax'], label='ax')
axs[0].plot(fly.index, fly['ay'], label='ay')
axs[0].plot(fly.index, fly['az'], label='az')
axs[0].set_title('100m Fly Acceleration')

# Plot gyro data for Fly dataset
axs[1].plot(fly.index, fly['gx'], label='gx')
axs[1].plot(fly.index, fly['gy'], label='gy')
axs[1].plot(fly.index, fly['gz'], label='gz')
axs[1].set_title('100m Fly Gyro')
# Out:
# Text(0.5, 1.0, '100m Fly Gyro')

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot acceleration data for Back dataset
axs[0].plot(back.index, back['ax'], label='ax')
axs[0].plot(back.index, back['ay'], label='ay')
axs[0].plot(back.index, back['az'], label='az')
axs[0].set_title('100m Back Acceleration')

# Plot gyro data for Back dataset
axs[1].plot(back.index, back['gx'], label='gx')
axs[1].plot(back.index, back['gy'], label='gy')
axs[1].plot(back.index, back['gz'], label='gz')
axs[1].set_title('100m Back Gyro')
# Out:
# Text(0.5, 1.0, '100m Back Gyro')

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot acceleration data for Breast dataset
axs[0].plot(breast.index, breast['ax'], label='ax')
axs[0].plot(breast.index, breast['ay'], label='ay')
axs[0].plot(breast.index, breast['az'], label='az')
axs[0].set_title('100m Breast Acceleration')

# Plot gyro data for Breast dataset
axs[1].plot(breast.index, breast['gx'], label='gx')
axs[1].plot(breast.index, breast['gy'], label='gy')
axs[1].plot(breast.index, breast['gz'], label='gz')
axs[1].set_title('100m Breast Gyro')
# Out:
# Text(0.5, 1.0, '100m Breast Gyro')

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot acceleration data for Free dataset
axs[0].plot(free.index, free['ax'], label='ax')
axs[0].plot(free.index, free['ay'], label='ay')
axs[0].plot(free.index, free['az'], label='az')
axs[0].set_title('100m Free Acceleration')

# Plot gyro data for Free dataset
axs[1].plot(free.index, free['gx'], label='gx')
axs[1].plot(free.index, free['gy'], label='gy')
axs[1].plot(free.index, free['gz'], label='gz')
axs[1].set_title('100m Free Gyro')
# Out:
# Text(0.5, 1.0, '100m Free Gyro')

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))

# Plot acceleration data for Free Quat dataset
axs[0].plot(free_quat.index, free_quat['ax'], label='ax')
axs[0].plot(free_quat.index, free_quat['ay'], label='ay')
axs[0].plot(free_quat.index, free_quat['az'], label='az')
axs[0].set_title('100m Free Acceleration (BNO085 Dataset)')

# Plot gyro data for Free Quat dataset
axs[1].plot(free_quat.index, free_quat['gx'], label='gx')
axs[1].plot(free_quat.index, free_quat['gy'], label='gy')
axs[1].plot(free_quat.index, free_quat['gz'], label='gz')
axs[1].set_title('100m Free Gyro (BNO085 Dataset)')
# Out:
# Text(0.5, 1.0, '100m Free Gyro (BNO085 Dataset)')

# %% [markdown]
# ### Data Preprocessing for LSTM Classifier
